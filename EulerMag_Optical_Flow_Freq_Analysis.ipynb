# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install gdown
# !gdown --id 1RggdfEs4RyBQKNELokmhCvJ2dUY9KsDl

# 1RggdfEs4RyBQKNELokmhCvJ2dUY9KsDl
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Dataset.zip"
extract_path = "/content/extracted_dataset"

# Check if zip file exists
if not os.path.exists(zip_path):
    print(f"Error: Zip file '{zip_path}' does not exist.")
    exit()

# Check contents of the zip file
print("Contents of the zip file:")
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    for member in zip_ref.namelist():
        print(member)

# Create extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the zip file
print(f"\nExtracting zip file to: {extract_path}")
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print("Extraction completed!")

# Check contents of the extracted directory
print(f"\nContents of the extracted directory '{extract_path}':")
if os.path.exists(extract_path):
    for root, dirs, files in os.walk(extract_path):
        level = root.replace(extract_path, '').count(os.sep)
        indent = ' ' * 4 * (level)
        # print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        # for f in files:
        #     print('{}{}'.format(subindent, f))
else:
    print(f"Extraction directory '{extract_path}' does not exist.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0723.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0728.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0731.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0732.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0733.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0734.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0737.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0738.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0739.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0742.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0743.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0746.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0747.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0748.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0751.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0757.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0758.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0759.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0760.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0764.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0766.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0768.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0769.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0770.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0772.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0775.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0777.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0783.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0786.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0788.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0794.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0796.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0804.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0805.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0806.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0816.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0817.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0818.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0824.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0827.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0831.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0838.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0842.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0844.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0852.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0854.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0857.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0859.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0861.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0862.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0868.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0870.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0871.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0872.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0876.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0878.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0879.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0882.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0892.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0897.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0899.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0901.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0918.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0920.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0921.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0922.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0929.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0930.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0943.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0947.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0948.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0949.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0952.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0954.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0955.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0963.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0965.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0969.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0974.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0985.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0990.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_0995.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1004.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1007.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1017.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1020.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1026.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1027.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1030.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1033.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1043.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1060.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1061.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1063.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1072.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1073.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1075.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1078.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1087.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1094.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1095.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1096.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1101.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1102.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1105.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1109.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1110.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1113.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1125.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1133.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1135.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1138.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1140.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1143.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1146.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1149.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1163.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1167.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1168.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1177.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1183.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1185.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1186.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1188.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1189.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1194.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1195.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1196.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1202.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1205.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1207.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1208.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1215.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1217.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1218.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1220.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1222.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1225.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1227.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1228.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1235.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1238.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1242.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1244.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1249.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1255.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1259.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1260.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1262.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1265.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1269.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1271.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1275.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1292.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1293.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1294.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1296.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1304.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1305.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1307.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1308.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1309.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1311.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1314.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1323.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1325.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1326.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1327.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1328.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1329.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1335.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1337.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1341.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1347.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1349.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1353.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1363.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1371.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1373.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1377.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1379.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1383.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1389.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1396.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1398.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1405.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1406.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1412.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1413.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1416.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1420.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1425.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1434.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1438.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1441.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1456.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1461.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1462.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1468.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1469.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1476.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1481.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1486.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1488.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1491.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1492.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1497.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1501.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1504.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1507.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1508.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1511.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1519.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1521.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1527.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1531.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1540.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1543.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1545.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1546.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1547.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1549.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1552.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1560.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1561.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1565.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1568.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1569.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1574.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1577.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1578.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1579.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1580.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1581.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1585.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1590.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1591.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1598.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1602.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1604.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1610.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1612.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1613.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1614.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1616.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1618.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1619.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1620.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1628.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1632.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1644.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1648.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1654.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1655.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1656.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1658.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1659.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1669.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1671.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1675.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1678.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1680.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1681.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1684.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1686.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1689.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1695.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1701.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1706.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1707.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1708.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1711.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1715.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1724.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1726.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1728.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1730.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1731.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1734.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1735.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1739.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1742.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1745.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1748.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1750.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1756.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1759.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1760.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1761.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1764.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1780.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1783.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1787.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1788.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1789.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1794.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1798.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1799.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1800.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1801.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1806.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1807.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1816.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1818.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1819.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1821.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1823.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1824.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1827.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1829.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1833.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1836.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1840.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1841.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1843.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1848.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1850.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1852.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1854.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1858.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1860.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1861.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1865.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1866.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1871.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1873.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1875.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1876.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1877.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1883.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1886.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1888.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1893.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1894.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1895.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1906.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1909.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1913.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1917.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1918.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1921.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1923.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1924.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1929.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1933.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1946.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1955.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1966.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1967.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1971.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1975.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1982.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1984.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1986.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1993.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1995.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1996.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_1997.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2003.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2005.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2010.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2015.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2017.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2018.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2025.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2032.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2034.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2037.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2050.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2053.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2055.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2056.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2061.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2066.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2067.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2069.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2070.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2071.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2072.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2075.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2076.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2077.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2079.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2080.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2086.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2091.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2096.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2098.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2100.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2104.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2105.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2109.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2110.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2113.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2114.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2115.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2116.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2118.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2120.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2124.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2131.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2134.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2137.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2142.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2145.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2146.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2149.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2157.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2162.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2163.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2167.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2173.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2177.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2179.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2183.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2185.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2186.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2188.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2189.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2195.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2197.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2200.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2203.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2214.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2226.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2234.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2235.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2238.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2243.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2245.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2247.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2252.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2253.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2254.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2258.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2266.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2267.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2269.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2272.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2273.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2274.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2275.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2276.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2279.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2281.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2287.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2289.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2294.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2296.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2297.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2298.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2299.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2303.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2305.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2319.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2326.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2336.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2338.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2344.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2345.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2360.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2363.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2368.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2369.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2372.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2382.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2387.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2391.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2392.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2402.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2403.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2406.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2410.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2411.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2417.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2421.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2426.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2429.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2430.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2432.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2441.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2445.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2449.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2450.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2454.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2456.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2459.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2461.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2467.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2473.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2475.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2479.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2481.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2491.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2494.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2498.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2499.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2501.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2505.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2506.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2510.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2511.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2518.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2520.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2522.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2523.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2528.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2533.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2537.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2538.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2540.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2548.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2551.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2554.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2560.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2565.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2570.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2571.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2573.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2576.png
# Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm /frame_2579.png
# ...
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2946.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2949.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2951.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2962.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2964.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2970.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2977.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2989.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_2991.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3001.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3007.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3010.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3014.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3020.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3031.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3036.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3040.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3044.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3051.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3056.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3057.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3067.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3073.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3075.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3078.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3080.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3091.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3093.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3102.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3105.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3110.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3114.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3115.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3116.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3117.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3120.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3126.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3131.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3135.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3145.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3152.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3153.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3155.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3158.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3162.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3164.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3171.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3173.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3174.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3177.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3184.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3188.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3194.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3203.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3206.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3211.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3217.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3223.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3237.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3242.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3243.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3248.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3249.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3250.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3254.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3261.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3267.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3282.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3285.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3310.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3314.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3317.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3322.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3325.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3340.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3341.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3346.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3355.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3365.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3374.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3380.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3382.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3402.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3416.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3430.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3432.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3439.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3440.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3443.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3444.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3447.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3455.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3457.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3463.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3471.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3472.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3480.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3481.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3484.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3492.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3518.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3523.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3526.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3533.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3536.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3550.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3554.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3556.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3564.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3570.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3576.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3579.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3582.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3586.png
# Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 /frame_3588.png
#
# Extracting zip file to: /content/extracted_dataset
# Extraction completed!
#
# Contents of the extracted directory '/content/extracted_dataset':

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.ndimage import gaussian_filter1d
from scipy.fft import fft, fftfreq
from scipy.signal import spectrogram
import os
from scipy.stats import skew, kurtosis, entropy
import re

# -------------------------------------------------------------------
# 1. CONFIGURATION - MODIFY THESE VALUES
# -------------------------------------------------------------------
# The root directory containing your dataset (e.g., .../250 RPM/)
DATA_ROOT = "/content/extracted_dataset/Dataset/250 RPM"

# A single base directory where all output folders will be created
BASE_OUTPUT_DIR = "/content/drive/MyDrive/Video_Analysis_Outputs"

# Frames Per Second (FPS) of the original videos.
FPS = 30

# Define the Region of Interest (ROI) you want to analyze.
# Format: (x_coordinate, y_coordinate, width, height)
# To find these values, open a sample frame and use an image editor
# to find the pixel coordinates of the top-left corner and the box size.
ROI = (100, 150, 200, 200) # EXAMPLE - CHANGE THIS

# Eulerian Magnification Parameters
ALPHA = 30
FILTER_SIZE = 5
# -------------------------------------------------------------------

# --- Define paths for organized output folders ---
EULERIAN_VIDEO_OUTPUT_DIR = os.path.join(BASE_OUTPUT_DIR, "Eulerian_Videos")
OPTICAL_FLOW_VIDEO_OUTPUT_DIR = os.path.join(BASE_OUTPUT_DIR, "Optical_Flow_Videos")
ANALYSIS_PLOT_OUTPUT_DIR = os.path.join(BASE_OUTPUT_DIR, "Analysis_Plots")
CSV_OUTPUT_DIR = os.path.join(BASE_OUTPUT_DIR, "CSV_Features")

# --- Create output directories if they don't exist ---
for path in [EULERIAN_VIDEO_OUTPUT_DIR, OPTICAL_FLOW_VIDEO_OUTPUT_DIR, ANALYSIS_PLOT_OUTPUT_DIR, CSV_OUTPUT_DIR]:
    os.makedirs(path, exist_ok=True)


# Function to load and sort frames from a directory
def load_frames_from_directory(directory_path):
    frames = []
    filepaths = sorted(
        [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith('.png')],
        key=lambda f: int(re.search(r'(\d+)', os.path.basename(f)).group(1)) # Natural sort
    )
    if not filepaths:
        return None
    for f_path in filepaths:
        frame = cv2.imread(f_path)
        if frame is not None:
            frames.append(frame)
    print(f"Loaded {len(frames)} frames from {os.path.basename(directory_path)}.")
    return frames

# Function to crop frames to the predefined ROI
# def crop_frames_to_roi(frames, roi):
#     x, y, w, h = roi
#     cropped_frames = [frame[y:y+h, x:x+w] for frame in frames]
#     return cropped_frames

# Eulerian magnification
def eulerian_magnification(frames, alpha=30, filter_size=5):
    float_frames = [np.float32(frame) for frame in frames]
    enhanced_frames = []
    for frame in float_frames:
        smoothed = gaussian_filter1d(frame, filter_size, axis=0)
        smoothed = gaussian_filter1d(smoothed, filter_size, axis=1)
        amplified = (frame - smoothed) * alpha
        enhanced = np.clip(smoothed + amplified, 0, 255)
        enhanced_frames.append(enhanced.astype(np.uint8))
    return enhanced_frames

# Optical Flow-based vertical displacement
def extract_vertical_displacement(frames):
    vertical_signal = []
    if not frames: return np.array([])
    prev_gray = cv2.cvtColor(frames[0], cv2.COLOR_BGR2GRAY).astype(np.float32)
    for frame in frames[1:]:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY).astype(np.float32)
        flow = cv2.calcOpticalFlowFarneback(prev_gray, gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        vertical_movement = flow[..., 1].mean()
        vertical_signal.append(vertical_movement)
        prev_gray = gray
    return np.array(vertical_signal)

# Save video (magnified or optical flow)
def save_video(frames, output_path, fps, is_color=True):
    if not frames: return
    h, w = frames[0].shape[:2]
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (w, h), isColor=is_color)
    for frame in frames:
        out.write(frame)
    out.release()
    print(f"-> Saved video to {output_path}")

def save_optical_flow_video(frames, output_path, fps):
    if not frames: return
    h, w, _ = frames[0].shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (w, h), isColor=True)
    prev_gray = cv2.cvtColor(frames[0], cv2.COLOR_BGR2GRAY)

    for next_frame_color in frames[1:]:
        next_gray = cv2.cvtColor(next_frame_color, cv2.COLOR_BGR2GRAY)
        flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
        mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
        hsv = np.zeros_like(frames[0])
        hsv[..., 1] = 255
        hsv[..., 0] = ang * 180 / np.pi / 2
        hsv[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
        bgr = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
        out.write(bgr)
        prev_gray = next_gray
    out.release()
    print(f"-> Saved optical flow video to {output_path}")

# Signal analysis and plotting functions (same as before)
def analyze_signal(signal, fps):
    N = len(signal)
    if N == 0: return {}, {}, None, None, None
    T = 1.0 / fps
    yf = fft(signal)
    xf = fftfreq(N, T)[:N // 2]
    amplitude = 2.0 / N * np.abs(yf[:N // 2])
    norm_amp = amplitude / np.sum(amplitude) if np.sum(amplitude) != 0 else amplitude
    freq_features = {
        "Total Energy": np.sum(amplitude ** 2),
        "Max Amplitude": np.max(amplitude) if amplitude.size > 0 else 0,
        "Frequency of Max Amp": xf[np.argmax(amplitude)] if amplitude.size > 0 else 0,
        "Spectral Centroid": np.sum(xf * amplitude) / np.sum(amplitude) if np.sum(amplitude) != 0 else 0,
        "Spectral Entropy": entropy(norm_amp) if norm_amp.size > 0 else 0
    }
    time_features = {"Mean": np.mean(signal), "Std Dev": np.std(signal), "Variance": np.var(signal), "Skewness": skew(signal), "Kurtosis": kurtosis(signal), "Peak-to-Peak": np.ptp(signal)}
    f, t, Sxx = spectrogram(signal, fs=fps, nperseg=min(N, 64))
    return time_features, freq_features, xf, amplitude, (f, t, Sxx)

def plot_and_save_results(signal, xf, amplitude, spectrogram_data, features, output_path):
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, axs = plt.subplots(3, 1, figsize=(12, 12))
    axs[0].plot(signal, color='royalblue')
    axs[0].set_title("Vibration Time Series (Vertical Displacement)", fontsize=14)
    axs[0].set_xlabel("Frame Number", fontsize=10)
    axs[0].set_ylabel("Mean Vertical Flow", fontsize=10)
    axs[1].plot(xf, amplitude, color='green')
    axs[1].set_title("Frequency Spectrum (FFT)", fontsize=14)
    axs[1].set_xlabel("Frequency (Hz)", fontsize=10)
    axs[1].set_ylabel("Amplitude", fontsize=10)
    f, t, Sxx = spectrogram_data
    spec = axs[2].pcolormesh(t, f, 10 * np.log10(Sxx + 1e-9), shading='gouraud', cmap='viridis')
    axs[2].set_title("Spectrogram", fontsize=14)
    axs[2].set_ylabel("Frequency [Hz]", fontsize=10)
    axs[2].set_xlabel("Time [sec]", fontsize=10)
    fig.colorbar(spec, ax=axs[2], label='Intensity (dB)')
    features_text = '\n'.join([f'{k}: {v:.4f}' for k, v in features.items()])
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    fig.text(0.5, -0.01, features_text, transform=fig.transFigure, fontsize=10, verticalalignment='top', bbox=props, ha='center')
    plt.tight_layout(rect=[0, 0.05, 1, 1])
    plt.savefig(output_path, bbox_inches='tight')
    plt.close(fig)
    print(f"-> Saved plot to {output_path}")

# -------------------------------------------------------------------
# MAIN PROCESSING LOOP
# -------------------------------------------------------------------
def process_all_directories(root_dir):
    for dirpath, dirnames, filenames in os.walk(root_dir):
        if any(f.lower().endswith('.png') for f in filenames):
            print(f"\n{'='*50}\nProcessing Directory: {dirpath}\n{'='*50}")

            # Create a unique base name from the folder structure
            relative_path = os.path.relpath(dirpath, root_dir)
            base_filename = relative_path.replace(os.sep, '_')

            try:
                frames = load_frames_from_directory(dirpath)
                if not frames: continue

                print("Cropping frames to ROI...")
                # roi_frames = crop_frames_to_roi(frames, ROI)

                print("Applying Eulerian Magnification...")
                enhanced_frames = eulerian_magnification(frames, alpha=ALPHA, filter_size=FILTER_SIZE)

                print("Calculating vertical displacement signal...")
                vibration_signal = extract_vertical_displacement(enhanced_frames)

                print("Analyzing signal...")
                time_f, freq_f, xf, amp, spec_data = analyze_signal(vibration_signal, FPS)
                if time_f is None: continue

                # Save all outputs to their respective centralized folders
                print("Saving results...")
                # 1. Eulerian Video
                euler_path = os.path.join(EULERIAN_VIDEO_OUTPUT_DIR, f"{base_filename}_eulerian.mp4")
                save_video(enhanced_frames, euler_path, FPS)

                # 2. Optical Flow Video
                flow_path = os.path.join(OPTICAL_FLOW_VIDEO_OUTPUT_DIR, f"{base_filename}_flow.mp4")
                save_optical_flow_video(enhanced_frames, flow_path, FPS)

                # 3. Features CSV
                all_features = {**time_f, **freq_f}
                df_features = pd.DataFrame([all_features])
                csv_path = os.path.join(CSV_OUTPUT_DIR, f"{base_filename}_features.csv")
                df_features.to_csv(csv_path, index=False)
                print(f"-> Saved features to {csv_path}")

                # 4. Analysis Plot
                plot_path = os.path.join(ANALYSIS_PLOT_OUTPUT_DIR, f"{base_filename}_analysis.png")
                plot_and_save_results(vibration_signal, xf, amp, spec_data, all_features, plot_path)

            except Exception as e:
                print(f"!!! An error occurred while processing {dirpath}: {e}")
                continue
    print("\n\nProcessing complete for all directories.")

# --- Run the main process ---
process_all_directories(DATA_ROOT)
# Out:
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/10 g/Angel from machine 49.7 _ Angel from glass 61.5 _ Distance 91.5 _ Height 120
# ==================================================
# Loaded 3600 frames from Angel from machine 49.7 _ Angel from glass 61.5 _ Distance 91.5 _ Height 120 .
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_10 g_Angel from machine 49.7 _ Angel from glass 61.5 _ Distance 91.5 _ Height 120 _eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_10 g_Angel from machine 49.7 _ Angel from glass 61.5 _ Distance 91.5 _ Height 120 _flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_10 g_Angel from machine 49.7 _ Angel from glass 61.5 _ Distance 91.5 _ Height 120 _features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_10 g_Angel from machine 49.7 _ Angel from glass 61.5 _ Distance 91.5 _ Height 120 _analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/10 g/From above
# ==================================================
# Loaded 3600 frames from From above.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_10 g_From above_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_10 g_From above_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_10 g_From above_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_10 g_From above_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/10 g/Distance 91.5cm _ Height 120cm
# ==================================================
# Loaded 3600 frames from Distance 91.5cm _ Height 120cm .
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_10 g_Distance 91.5cm _ Height 120cm _eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_10 g_Distance 91.5cm _ Height 120cm _flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_10 g_Distance 91.5cm _ Height 120cm _features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_10 g_Distance 91.5cm _ Height 120cm _analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/10 g/Angel from glass 68.5 _Angel from machine 88_Distance from machine 91.5
# ==================================================
# Loaded 3600 frames from Angel from glass 68.5 _Angel from machine 88_Distance from machine 91.5.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_10 g_Angel from glass 68.5 _Angel from machine 88_Distance from machine 91.5_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_10 g_Angel from glass 68.5 _Angel from machine 88_Distance from machine 91.5_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_10 g_Angel from glass 68.5 _Angel from machine 88_Distance from machine 91.5_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_10 g_Angel from glass 68.5 _Angel from machine 88_Distance from machine 91.5_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/16 cm distance _ 20 cm height
# ==================================================
# Loaded 3600 frames from 16 cm distance _ 20 cm height.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_16 cm distance _ 20 cm height_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_16 cm distance _ 20 cm height_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_16 cm distance _ 20 cm height_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_16 cm distance _ 20 cm height_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/11 cm distance and 12 height
# ==================================================
# Loaded 3600 frames from 11 cm distance and 12 height.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_11 cm distance and 12 height_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_11 cm distance and 12 height_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_11 cm distance and 12 height_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_11 cm distance and 12 height_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/12 h and 11 dist and 45 degree
# ==================================================
# Loaded 3600 frames from 12 h and 11 dist and 45 degree.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_12 h and 11 dist and 45 degree_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_12 h and 11 dist and 45 degree_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_12 h and 11 dist and 45 degree_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_12 h and 11 dist and 45 degree_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/11 dist
# ==================================================
# Loaded 3600 frames from 11 dist.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_11 dist_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_11 dist_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_11 dist_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_11 dist_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/11 dist from machine
# ==================================================
# Loaded 3600 frames from 11 dist from machine.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_11 dist from machine_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_11 dist from machine_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_11 dist from machine_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_11 dist from machine_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/11 cm distance from machine
# ==================================================
# Loaded 3600 frames from 11 cm distance from machine.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_11 cm distance from machine_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_11 cm distance from machine_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_11 cm distance from machine_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_11 cm distance from machine_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/18 cm distance _ height 0
# ==================================================
# Loaded 3600 frames from 18 cm distance _ height 0.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_18 cm distance _ height 0_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_18 cm distance _ height 0_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_18 cm distance _ height 0_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_18 cm distance _ height 0_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/11 cm dist and 12 height and 45 degree
# ==================================================
# Loaded 3600 frames from 11 cm dist and 12 height and 45 degree.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_11 cm dist and 12 height and 45 degree_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_11 cm dist and 12 height and 45 degree_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_11 cm dist and 12 height and 45 degree_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_11 cm dist and 12 height and 45 degree_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/18 dist and 0 height
# ==================================================
# Loaded 3600 frames from 18 dist and 0 height.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_18 dist and 0 height_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_18 dist and 0 height_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_18 dist and 0 height_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_18 dist and 0 height_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/11 cm and 12 height with 37g
# ==================================================
# Loaded 3600 frames from 11 cm and 12 height with 37g.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_11 cm and 12 height with 37g_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_11 cm and 12 height with 37g_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_11 cm and 12 height with 37g_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_11 cm and 12 height with 37g_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/37 g/15 cm and height 0
# ==================================================
# Loaded 3600 frames from 15 cm and height 0.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_37 g_15 cm and height 0_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_37 g_15 cm and height 0_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_37 g_15 cm and height 0_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_37 g_15 cm and height 0_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/Outer Ring/From Above
# ==================================================
# Loaded 3600 frames from From Above.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_Outer Ring_From Above_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_Outer Ring_From Above_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_Outer Ring_From Above_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_Outer Ring_From Above_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/Outer Ring/Distance 91.5 from machine _ Height 120 cm
# ==================================================
# Loaded 3600 frames from Distance 91.5 from machine _ Height 120 cm .
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_Outer Ring_Distance 91.5 from machine _ Height 120 cm _eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_Outer Ring_Distance 91.5 from machine _ Height 120 cm _flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_Outer Ring_Distance 91.5 from machine _ Height 120 cm _features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_Outer Ring_Distance 91.5 from machine _ Height 120 cm _analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/Outer Ring/Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120
# ==================================================
# Loaded 3600 frames from Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 .
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_Outer Ring_Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 _eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_Outer Ring_Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 _flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_Outer Ring_Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 _features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_Outer Ring_Angel from machine 49.7 _ Angel from glass 61.5_ Distance from machine 91.5_ height 120 _analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Fault/Outer Ring/Angel from glass 68.5 _Angel from machine 88 _ Distance from machine 91.5
# ==================================================
# Loaded 3600 frames from Angel from glass 68.5 _Angel from machine 88 _ Distance from machine 91.5.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Fault_Outer Ring_Angel from glass 68.5 _Angel from machine 88 _ Distance from machine 91.5_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Fault_Outer Ring_Angel from glass 68.5 _Angel from machine 88 _ Distance from machine 91.5_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Fault_Outer Ring_Angel from glass 68.5 _Angel from machine 88 _ Distance from machine 91.5_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Fault_Outer Ring_Angel from glass 68.5 _Angel from machine 88 _ Distance from machine 91.5_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Normal/10 distance
# ==================================================
# Loaded 3600 frames from 10 distance.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Normal_10 distance_eulerian.mp4
# -> Saved optical flow video to /content/drive/MyDrive/Video_Analysis_Outputs/Optical_Flow_Videos/Normal_10 distance_flow.mp4
# -> Saved features to /content/drive/MyDrive/Video_Analysis_Outputs/CSV_Features/Normal_10 distance_features.csv
# -> Saved plot to /content/drive/MyDrive/Video_Analysis_Outputs/Analysis_Plots/Normal_10 distance_analysis.png
#
# ==================================================
# Processing Directory: /content/extracted_dataset/Dataset/250 RPM/Normal/From above
# ==================================================
# Loaded 3600 frames from From above.
# Cropping frames to ROI...
# Applying Eulerian Magnification...
# Calculating vertical displacement signal...
# Analyzing signal...
# Saving results...
# -> Saved video to /content/drive/MyDrive/Video_Analysis_Outputs/Eulerian_Videos/Normal_From above_eulerian.mp4
